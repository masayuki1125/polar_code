# %%
import numpy as np
from polar_code import polar_code
from AWGN import _AWGN
from polar_construction import Improved_GA
#import sympy as sym

# %%
class PAM():
  def __init__(self,N):
    self.N=N
    self.K=N//2
    #EbNodB1>EbNodB2
    self.EbNodB1=20
    #self.EbNodB2=10
    
    EbNo1 = 10 ** (self.EbNodB1 / 10)
    self.No1=1/EbNo1
    #EbNo2 = 10 ** (self.EbNodB2 / 10)
    #self.No2=1/EbNo2
    
    self.beta=0.5
    
    self.ch=_AWGN()
    self.cd=polar_code(self.N,self.K)
    
    self.filename="PAM_polar_Improved_GA{}_{}".format(self.N,self.K)
    
    #self.intleav,self.deintleav=self.interleaver(N)
    
  @staticmethod
  def interleaver(N):
    intleav=np.arange(N)
    #デコーダごとに必要なビットの中でインターリーブする
    #前半と後半ごとにインターリーブする
    np.random.shuffle(intleav[:len(intleav)])
    np.random.shuffle(intleav[len(intleav):])
    deintleav=np.argsort(intleav)
    return intleav,deintleav
  
  def PAM_encode(self):
    info,cwd=self.cd.polar_encode()
    return info,cwd
  
  def channel(self,cwd,beta):
    #interleave codeword
    #cwd=cwd[self.intleav]
    
    [cwd1,cwd2]=np.split(cwd,2)
    
    const1=self.ch.generate_QAM(cwd1)
    const2=self.ch.generate_QAM(cwd2)
    res_const=beta*const1*(-1*const2)+const2
    #print(res_const)
    return res_const
  
  @staticmethod
  def calc_exp(x,A,No):
    #解が0にならないように計算する
    res=np.zeros(len(x))
    for i in range(len(x)):
      if (x[i]-A)**2/No<30:
        res[i]=np.exp(-1*(x[i]-A)**2/No)
      else:
        res[i]=10**(-15)
    return res
  
  def calc_LLR(self,x,No):
    A1=self.calc_exp(x,-1-self.beta,No)
    A2=self.calc_exp(x,-1+self.beta,No)
    A3=self.calc_exp(x,1-self.beta,No)
    A4=self.calc_exp(x,1+self.beta,No)
    
    y2=np.log((A3+A4)/(A1+A2))
    y1=np.log((A2+A3)/(A1+A4))
    #print(y2)
    #print(y1)
    
    return np.concatenate([y1,y2])
  
  def decode1(self,res_const,No1):
    RX_const=self.ch.add_AWGN(res_const,No1)
    RX_const=RX_const.real #In-paseのみ取り出す
    #print(RX_const)
    Lc=-1*self.calc_LLR(RX_const,No1)
    #print(Lc)
    EST_cwd=self.cd.polar_decode(Lc)
    
    #de-interleave codeword
    #EST_cwd=EST_cwd[self.deintleav]
    
    EST_cwd1=EST_cwd[:len(EST_cwd)//2]
    return EST_cwd1
    
  def decode2(self,res_const,No2):
    RX_const=self.ch.add_AWGN(res_const,No2)
    RX_const=RX_const.real #In_phaseのみ取り出す
    Lc=-1*self.calc_LLR(RX_const,No2)
    
    EST_cwd=self.cd.polar_decode(Lc)
    
    #de-interleave codeword
    #EST_cwd=EST_cwd[self.deintleav]
    
    EST_cwd2=EST_cwd[len(EST_cwd)//2:]
    return EST_cwd2
  
  def PAM_decode(self,res_const,No1,No2):
    EST_cwd1=self.decode1(res_const,No1)
    EST_cwd2=self.decode2(res_const,No2)
    
    return EST_cwd1,EST_cwd2
  
  def main_func(self,EbNodB2):
    #calc No2
    EbNo2 = 10 ** (EbNodB2 / 10)
    No2=1/EbNo2
    
    #change construction
    if EbNodB2!=self.cd.design_SNR:
      self.cd.design_SNR=EbNodB2
      #decide frozen_bits
      count=0
      f1,i1=self.cd.const.main_const(self.N,self.K,self.cd.design_SNR,self.beta,np.arange(self.N//2,self.N),np.arange(0,self.N//2))
      while True:
        self.cd.frozen_bits,self.cd.info_bits=self.cd.const.main_const(self.N,self.K,self.cd.design_SNR,self.beta,i1,f1)
        if np.all(i1==self.cd.info_bits):
          break
        else:
          f1=self.cd.frozen_bits
          i1=self.cd.info_bits
          count+=1
          print(count)
    
    info,cwd=self.PAM_encode()
    
    res_const=self.channel(cwd,self.beta)
    
    
    EST_info1,EST_info2=self.PAM_decode(res_const,self.No1,No2)

    EST_info=np.concatenate([EST_info1,EST_info2])
    
    return info,EST_info

# %%
if __name__=="__main__":
  N=1024
  ma=PAM(N)
  a,b=ma.main_func(2)
  #print(a)
  #print(b)
  print(np.sum(a!=b))
  print(a!=b)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-41c9d125da54> in <module>
#       1 if __name__=="__main__":
#       2   N=1024
# ----> 3   ma=PAM(N)
#       4   a,b=ma.main_func(2)
#       5   #print(a)
#
# <ipython-input-5-f05d521aa726> in __init__(self, N)
#      15
#      16     self.ch=_AWGN()
# ---> 17     self.cd=polar_code(self.N,self.K)
#      18
#      19     self.filename="PAM_polar_Improved_GA{}_{}".format(self.N,self.K)
#
# ~/My Drive/programming/polar_code/polar_code.py in __init__(self, N, K)
#     601 class polar_code(encoding,decoding):
#     602   def __init__(self,N,K):
# --> 603     super().__init__(N,K)
#     604
#     605   def main_func(self,EbNodB):
#
# ~/My Drive/programming/polar_code/polar_code.py in __init__(self, N, K)
#     154 class encoding(coding):
#     155   def __init__(self,N,K):
# --> 156     super().__init__(N,K)
#     157
#     158   def generate_information(self):
#
# ~/My Drive/programming/polar_code/polar_code.py in __init__(self, N, K)
#     277
#     278   def __init__(self,N,K):
# --> 279     super().__init__(N,K)
#     280
#     281   @staticmethod
#
# ~/My Drive/programming/polar_code/polar_code.py in __init__(self, N, K)
#      57
#      58     #flozen_bit selection
# ---> 59     self.frozen_bits,self.info_bits=self.choose_frozen_bits(self.design_SNR)
#      60
#      61     if self.systematic_polar==True:
#
# ~/My Drive/programming/polar_code/polar_code.py in choose_frozen_bits(self, design_SNR, beta)
#      76       self.filename="polar_SCL_{}_{}_{}".format(self.N,self.K,self.list_size)
#      77       #construction
# ---> 78       frozen_bits,info_bits=self.const.main_const(self.N,self.K,design_SNR,beta)
#      79
#      80     elif self.decoder_var==2:
#
# ~/My Drive/programming/polar_code/polar_construction.py in main_const(self, N, K, high_des, beta, ind_high_des, ind_low_des)
#     259       for j in range(gamma.shape[1]):
#     260         if (j//2**(n-i))%2==0:
# --> 261           gamma[i,j]=self.left_operation(gamma[i-1,j],gamma[i-1,j+2**(n-i)])
#     262
#     263         else :
#
# ~/My Drive/programming/polar_code/polar_construction.py in left_operation(self, gamma1, gamma2)
#     228     else:
#     229
# --> 230       gamma=self.xi_inv(zeta1+math.log(2-math.e**zeta1))
#     231       #tmp=self.maxstr(zeta1,zeta2)
#     232       #zeta=self.maxstr(tmp,zeta1-zeta2)
#
# ~/My Drive/programming/polar_code/polar_construction.py in xi_inv(self, zeta)
#      83
#      84     elif zeta<=self.Z_2:
# ---> 85       gamma=self.bisection_method(zeta)
#      86       #gamma=-4*zeta
#      87
#
# ~/My Drive/programming/polar_code/polar_construction.py in bisection_method(self, zeta)
#     122       c=(b+a)/2 #center value
#     123
# --> 124       if f(c)>=zeta:
#     125         a=c
#     126         error=b-a
#
# ~/My Drive/programming/polar_code/polar_construction.py in f(x)
#     106
#     107     def f(x):
# --> 108       zeta=-1*x/4+math.log(math.pi)/2-math.log(x)/2+math.log(1-(math.pi**2)/(4*x)+self.K_0/(x**2))
#     109       return zeta
#     110
#
# KeyboardInterrupt:
